# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

path = "videos_racing/"

vid = []
for i in range(27):
    file = "openaigym.video." + str(i) + ".27272.video000000.mp4"
    #print(path+file)
    vidcap = cv2.VideoCapture(path+file)
    success, tmp = vidcap.read()
    tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)
    tmp = tmp[150:350,200:400,:]
    count = 0
    while success :    
        success,image = vidcap.read()
        if success and count % 2 == 0 :
            image = image[150:350,200:400,:]
            image = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            tmp = np.vstack((tmp,image))
            #print('Read a new frame: ', success, 'Count: ', count)
        count += 1
    tmp.resize(501,200,200,3)
    tmp = tmp[21:,:,:,:]
    print("%d video, %d count" %(i, count))
    #os._exit()
    vid.append(tmp)

vid = np.array(vid)
# Out:
# 0 video, 1001 count
# 1 video, 1001 count
# 2 video, 1001 count
# 3 video, 1001 count
# 4 video, 1001 count
# 5 video, 1001 count
# 6 video, 1001 count
# 7 video, 1001 count
# 8 video, 1001 count
# 9 video, 1001 count
# 10 video, 1001 count
# 11 video, 1001 count
# 12 video, 1001 count
# 13 video, 1001 count
# 14 video, 1001 count
# 15 video, 1001 count
# 16 video, 1001 count
# 17 video, 1001 count
# 18 video, 1001 count
# 19 video, 1001 count
# 20 video, 1001 count
# 21 video, 1001 count
# 22 video, 1001 count
# 23 video, 1001 count
# 24 video, 1001 count
# 25 video, 1001 count
# 26 video, 1001 count

# %%
vid.shape
# Out:
# (27, 480, 200, 200, 3)

# %%
from sklearn.externals import joblib

joblib.dump(vid, 'racing_norm.pkl')
# Out:
# ['racing_norm.pkl']

# %%
plt.imshow(vid[26,52])

# %%
plt.imshow(vid[12,2,:,:,:])
